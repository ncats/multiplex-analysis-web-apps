# %%
import os 
import pandas as pd 
import scanpy as sc

os.chdir("/Users/bombina2/github/multiplex-analysis-web-apps")

adata = sc.read("input/clust_dat.h5ad")

adata
# Out:
# /Users/bombina2/miniconda3/envs/mawa-2024-02-08/lib/python3.11/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 47859 × 40
#     obs: 'Slide ID', 'tag', 'Cell X Position', 'Cell Y Position', 'Image ID_(standardized)', 'ROI ID_(standardized)', 'Centroid X (µm)_(standardized)', 'Centroid Y (µm)_(standardized)'
#     layers: 'counts'

# %%
sc.pp.pca(adata, n_comps=10)

adata
# Out:
# AnnData object with n_obs × n_vars = 47859 × 40
#     obs: 'Slide ID', 'tag', 'Cell X Position', 'Cell Y Position', 'Image ID_(standardized)', 'ROI ID_(standardized)', 'Centroid X (µm)_(standardized)', 'Centroid Y (µm)_(standardized)'
#     uns: 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=10)
sc.tl.umap(adata)
sc.pl.umap(adata)

adata.obsm["X_umap"]
# Out:
# array([[ 2.0827599,  4.525    ],
#        [ 3.4756582,  5.0129147],
#        [ 1.9437335,  4.7497396],
#        ...,
#        [ 0.9412184, -1.063999 ],
#        [-1.0968539,  8.988477 ],
#        [-1.9161322,  6.2224045]], dtype=float32)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=0)
sc.tl.umap(adata)
sc.pl.umap(adata)

adata.obsm["X_umap"]
# Out:
# array([[ 2.0827599,  4.525    ],
#        [ 3.4756582,  5.0129147],
#        [ 1.9437335,  4.7497396],
#        ...,
#        [ 0.9412184, -1.063999 ],
#        [-1.0968539,  8.988477 ],
#        [-1.9161322,  6.2224045]], dtype=float32)

# %%
import os 
import pandas as pd 
import scanpy as sc

os.chdir("/Users/bombina2/github/multiplex-analysis-web-apps")

adata = sc.read("input/clust_dat.h5ad")

sc.pp.neighbors(adata, n_neighbors=10, n_pcs=0)
sc.tl.umap(adata)
sc.pl.umap(adata)

adata.obsm["X_umap"]
# Out:
# /Users/bombina2/miniconda3/envs/mawa-2024-02-08/lib/python3.11/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# array([[ 2.0827599,  4.525    ],
#        [ 3.4756582,  5.0129147],
#        [ 1.9437335,  4.7497396],
#        ...,
#        [ 0.9412184, -1.063999 ],
#        [-1.0968539,  8.988477 ],
#        [-1.9161322,  6.2224045]], dtype=float32)
