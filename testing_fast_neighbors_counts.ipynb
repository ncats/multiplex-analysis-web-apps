# %% [markdown]
# ## Working
#
# It started out as good.
# Adding timing information kept it fast.
# setting intermediate dtype to int32 broke it
# did it at the end instead and kept it fast while making final result int32
# now good has been turned into bad (which is more complete) as best as possible while still keeping it fast; the following is the good result!

# %%
# This works

import scipy.spatial
import pandas as pd
import time
import numpy as np

# def fast_neighbors_counts_for_block(df_all_images, image_column_name, image_name, coord_column_names, phenotypes, radii, phenotype_column_name):
def fast_neighbors_counts_for_block(df_image, image_name, coord_column_names, phenotypes, radii, phenotype_column_name):
    # A block can be an image, ROI, etc. It's the entity over which it makes sense to calculate the neighbors of centers. Here, we're assuming it's an image, but in the SIT for e.g., we generally want it to refer to a ROI.

    # Print the image name
    print(f'Calculating neighbor counts for image {image_name} ({len(df_image)} cells)...')

    start_time = time.time()

    # Get the boolean series identifying the current image specified by image_name
    # ser_curr_image = df_all_images[image_column_name] == image_name

    # Get the number of cells in the current image
    # num_cells_in_image = ser_curr_image.sum()
    # num_cells_in_image = len(df_image)

    # Construct the KDTree for the entire current image. This represents the centers
    # center_tree = scipy.spatial.KDTree(df_all_images.loc[ser_curr_image, coord_column_names])
    center_tree = scipy.spatial.KDTree(df_image[coord_column_names])

    # Initialize a list to hold the dataframes of neighbor counts for each radius (not each radius range)
    # df_counts_holder = [pd.DataFrame(0, index=phenotypes, columns=range(num_cells_in_image)) for _ in radii]
    df_counts_holder = [pd.DataFrame(0, index=phenotypes, columns=df_image.index) for _ in radii]

    # For each phenotype...
    for neighbor_phenotype in phenotypes:

        # Get the boolean series identifying the current neighbor phenotype
        # ser_curr_neighbor_phenotype = df_all_images[phenotype_column_name] == neighbor_phenotype
        ser_curr_neighbor_phenotype = df_image[phenotype_column_name] == neighbor_phenotype

        # Construct the KDTree for the current phenotype in the entire current image. This represents the neighbors
        # curr_neighbor_tree = scipy.spatial.KDTree(df_all_images.loc[ser_curr_image & ser_curr_neighbor_phenotype, coord_column_names])
        curr_neighbor_tree = scipy.spatial.KDTree(df_image.loc[ser_curr_neighbor_phenotype, coord_column_names])

        # For each radius, which should be monotonically increasing and start with 0...
        for iradius, radius in enumerate(radii):

            # Get the list of lists containing the indices of the neighbors for each center
            neighbors_for_radius = center_tree.query_ball_tree(curr_neighbor_tree, radius)

            # In the correct dataframe (corresponding to the current radius), set the counts of neighbors (of the current phenotype) for each center
            df_counts_holder[iradius].loc[neighbor_phenotype, :] = [len(neighbors_for_center) for neighbors_for_center in neighbors_for_radius]

    # For each annulus, i.e., each radius range...
    df_counts_holder_annulus = []
    for iradius in range(len(radii) - 1):

        # Get the counts of neighbors in the current annulus
        df_counts_curr_annulus = df_counts_holder[iradius + 1] - df_counts_holder[iradius]

        # Rename the index to reflect the current radius range
        radius_range_str = f'({radii[iradius]}, {radii[iradius + 1]}]'
        df_counts_curr_annulus.index = [f'{phenotype} in {radius_range_str}' for phenotype in phenotypes]

        # Add a transpose of this (so centers are in rows and phenotypes/radii are in columns) to the running list of annulus dataframes
        df_counts_holder_annulus.append(df_counts_curr_annulus.T)

    # Concatenate the annulus dataframes to get the final dataframe of neighbor counts for the current image
    df_curr_counts = pd.concat(df_counts_holder_annulus, axis='columns')

    # Set the index of the final dataframe to correspond to that of the original dataframe
    # df_curr_counts.index = df_all_images[ser_curr_image].index
    # df_curr_counts.index = df_image.index

    df_curr_counts = df_curr_counts.astype(np.int32)

    print(f'  ...finished calculating neighbor counts for image {image_name} ({len(df_image)} cells) in {time.time() - start_time:.2f} seconds')

    # Return the final dataframe of neighbor counts for the current image
    return df_curr_counts

# %%
# This works

import os
import numpy as np
import utils

# Parameters
input_file = os.path.join('.', 'input', 'Combo_CSVfiles_20230327_152849.csv')
radii = np.array([0, 25, 50, 100, 150, 200])
coord_column_names = ['CentroidX', 'CentroidY']
image_column_name = 'ShortName'
phenotype_column_name = 'pheno_20230327_152849'
method = 'kdtree'

# Read in the datafile
df = pd.read_csv(input_file)
df = utils.downcast_dataframe_dtypes(pd.read_csv(input_file))

# To see mapping of phenotype names
# print(df.iloc[:, 83:92].drop_duplicates())

# Variables
image_names = sorted(df[image_column_name].unique())
phenotypes = df[phenotype_column_name].value_counts().index
# Out:
# ----
# Memory usage before conversion: 1070.30 MB
# Column ShortName was compressed from object to category
# Column ObjectId was compressed from int64 to int32
# Column XMin was compressed from int64 to int32
# Column XMax was compressed from int64 to int32
# Column YMin was compressed from int64 to int32
# Column YMax was compressed from int64 to int32
# Column CentroidXpix was compressed from float64 to float32
# Column CentroidYpix was compressed from float64 to float32
# Column CentroidX was compressed from float64 to float32
# Column CentroidY was compressed from float64 to float32
# Column Survival_5yr was compressed from int64 to category
# Column Outcome was compressed from int64 to category
# Column CellArea__m__ was compressed from float64 to float32
# Column CytoplasmArea__m__ was compressed from float64 to float32
# Column NucleusArea__m__ was compressed from float64 to float32
# Column NucleusPerimeter__m_ was compressed from float64 to float32
# Column NucleusRoundness was compressed from float64 to float32
# Column Ultivue_DAPIPositiveClassification was compressed from int64 to category
# Column Ultivue_DAPIPositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_DAPINucleusIntensity was compressed from float64 to float32
# Column Ultivue_DAPIPositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_DAPICytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_DAPICellIntensity was compressed from float64 to float32
# Column Ultivue_PD_L1PositiveClassification was compressed from int64 to category
# Column Ultivue_PD_L1PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_PD_L1NucleusIntensity was compressed from float64 to float32
# Column Ultivue_PD_L1PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_PD_L1CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_PD_L1CellIntensity was compressed from float64 to float32
# Column Ultivue_CD68PositiveClassification was compressed from int64 to category
# Column Ultivue_CD68PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_CD68NucleusIntensity was compressed from float64 to float32
# Column Ultivue_CD68PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_CD68CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_CD68CellIntensity was compressed from float64 to float32
# Column Ultivue_CD8PositiveClassification was compressed from int64 to category
# Column Ultivue_CD8PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_CD8NucleusIntensity was compressed from float64 to float32
# Column Ultivue_CD8PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_CD8CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_CD8CellIntensity was compressed from float64 to float32
# Column Ultivue_PD_1PositiveClassification was compressed from int64 to category
# Column Ultivue_PD_1PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_PD_1NucleusIntensity was compressed from float64 to float32
# Column Ultivue_PD_1PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_PD_1CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_PD_1CellIntensity was compressed from float64 to float32
# Column Ultivue_FOXP3PositiveClassification was compressed from int64 to category
# Column Ultivue_FOXP3PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_FOXP3NucleusIntensity was compressed from float64 to float32
# Column Ultivue_FOXP3PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_FOXP3CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_FOXP3CellIntensity was compressed from float64 to float32
# Column Ultivue_CK_SOX10PositiveClassification was compressed from int64 to category
# Column Ultivue_CK_SOX10PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_CK_SOX10NucleusIntensity was compressed from float64 to float32
# Column Ultivue_CK_SOX10PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_CK_SOX10CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_CK_SOX10CellIntensity was compressed from float64 to float32
# Column Ultivue_CD3PositiveClassification was compressed from int64 to category
# Column Ultivue_CD3PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_CD3NucleusIntensity was compressed from float64 to float32
# Column Ultivue_CD3PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_CD3CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_CD3CellIntensity was compressed from float64 to float32
# Column Ultivue_CD4PositiveClassification was compressed from int64 to category
# Column Ultivue_CD4PositiveNucleusClassification was compressed from int64 to category
# Column Ultivue_CD4NucleusIntensity was compressed from float64 to float32
# Column Ultivue_CD4PositiveCytoplasmClassification was compressed from int64 to category
# Column Ultivue_CD4CytoplasmIntensity was compressed from float64 to float32
# Column Ultivue_CD4CellIntensity was compressed from float64 to float32
# Column NOS2_COX2_COX2PositiveClassification was compressed from int64 to category
# Column NOS2_COX2_COX2PositiveNucleusClassification was compressed from int64 to category
# Column NOS2_COX2_COX2NucleusIntensity was compressed from float64 to float32
# Column NOS2_COX2_COX2PositiveCytoplasmClassification was compressed from int64 to category
# Column NOS2_COX2_COX2CytoplasmIntensity was compressed from float64 to float32
# Column NOS2_COX2_COX2CellIntensity was compressed from float64 to float32
# Column NOS2_COX2_NOS2PositiveClassification was compressed from int64 to category
# Column NOS2_COX2_NOS2PositiveNucleusClassification was compressed from int64 to category
# Column NOS2_COX2_NOS2NucleusIntensity was compressed from float64 to float32
# Column NOS2_COX2_NOS2PositiveCytoplasmClassification was compressed from int64 to category
# Column NOS2_COX2_NOS2CytoplasmIntensity was compressed from float64 to float32
# Column NOS2_COX2_NOS2CellIntensity was compressed from float64 to float32
# Column CD8_COX2_NOS2_ was compressed from int64 to category
# Column CD8_COX2_NOS2__1 was compressed from int64 to category
# Column CD8_COX2_NOS2__2 was compressed from int64 to category
# Column CD8_COX2_NOS2__3 was compressed from int64 to category
# Column CD8_COX2_NOS2__4 was compressed from int64 to category
# Column CD8_COX2_NOS2__5 was compressed from int64 to category
# Column CD8_COX2_NOS2__6 was compressed from int64 to category
# Column CD8_COX2_NOS2__7 was compressed from int64 to category
# Column pheno_20230327_152849 was compressed from object to category
# Column UMAP_1_20230327_152849 was compressed from float64 to float32
# Column UMAP_2_20230327_152849 was compressed from float64 to float32
# Column UMAP_ClusterIDs_20230327_152849 was compressed from int64 to int32
# Column UMAP_RowMask_20230327_152849 was compressed from int64 to category
# Memory usage after conversion: 296.51 MB
# Percent reduction in memory footprint: 72.30%

# %%
tuple_holder = []

for image_name in image_names:
    # print(fast_neighbors_counts_for_block(df[df[image_column_name] == image_name], image_name, coord_column_names, phenotypes, radii, phenotype_column_name).shape)  # 9.7, 15.0, 7.8, 8.1, 9.5, 8.8, 8.0, 11.6, 7.7, 8.5, 8.0
    tuple_holder.append((df[df[image_column_name] == image_name], image_name, coord_column_names, phenotypes, radii, phenotype_column_name))

# %%
# This works (5/7/24 at 2:27 PM )

for curr_tuple in tuple_holder[:4]:
    print(fast_neighbors_counts_for_block(*curr_tuple).shape)
# Out:
# Calculating neighbor counts for image p10197 (67685 cells)...
#   ...finished calculating neighbor counts for image p10197 (67685 cells) in 7.58 seconds
# (67685, 40)
# Calculating neighbor counts for image p10330 (62499 cells)...
#   ...finished calculating neighbor counts for image p10330 (62499 cells) in 9.23 seconds
# (62499, 40)
# Calculating neighbor counts for image p10929 (22783 cells)...
#   ...finished calculating neighbor counts for image p10929 (22783 cells) in 2.67 seconds
# (22783, 40)
# Calculating neighbor counts for image p11431 (109235 cells)...
#   ...finished calculating neighbor counts for image p11431 (109235 cells) in 14.68 seconds
# (109235, 40)

# %%
from itertools import starmap

# Apply the function to each tuple in tuple_holder
result = list(starmap(fast_neighbors_counts_for_block, tuple_holder[:4]))

# Print the shape of each result
for res in result:
    print(res.shape)
# Out:
# Calculating neighbor counts for image p10197 (67685 cells)...
#   ...finished calculating neighbor counts for image p10197 (67685 cells) in 7.58 seconds
# Calculating neighbor counts for image p10330 (62499 cells)...
#   ...finished calculating neighbor counts for image p10330 (62499 cells) in 10.26 seconds
# Calculating neighbor counts for image p10929 (22783 cells)...
#   ...finished calculating neighbor counts for image p10929 (22783 cells) in 2.74 seconds
# Calculating neighbor counts for image p11431 (109235 cells)...
#   ...finished calculating neighbor counts for image p11431 (109235 cells) in 15.17 seconds
# (67685, 40)
# (62499, 40)
# (22783, 40)
# (109235, 40)

# %%
# seems to work

from multiprocessing import Pool

# Create a pool of worker processes
with Pool(6) as p:
    # Apply the function to each tuple in tuple_holder
    result = p.starmap(fast_neighbors_counts_for_block, tuple_holder)

# Print the shape of each result
for res in result:
    print(res.shape)

# %%
df_counts = pd.concat(result, axis='index')
